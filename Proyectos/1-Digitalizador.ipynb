# %% [markdown]
# # Proyecto 1
#
# ## Digitalizar dibujos
#
# Este proyecto consiste en utilizar un método llamado **umbralización** para pasar de dibujos hechos a mano, como este:

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

# %%
dibujo = mpimg.imread('dibujo.jpg')
plt.imshow(dibujo)

# %% [markdown]
# Al mismo dibujo pero en digital, con los bordes bien marcados:

# %%
digital = mpimg.imread('digitalizado.jpg')
plt.imshow(digital)

# %% [markdown]
# La **umbralización** consiste en definir un número entre 0 y 255 como el **umbral**. Pixeles con valores por encima de este umbral adquieren el valor 255 (blanco), y pixeles con valores por debajo del umbral se convierten a 0 (negro).

# %%
# Tu código aquí
